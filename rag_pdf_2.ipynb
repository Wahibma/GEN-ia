
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: langchain in c:\users\wahib\appdata\roaming\python\python311\site-packages (0.3.21)
# Collecting langchain-openai
#   Obtaining dependency information for langchain-openai from https://files.pythonhosted.org/packages/07/7e/0d8838972ffead497b40cd42a1676f9ad90427d422c92dff2fb5461c4308/langchain_openai-0.3.12-py3-none-any.whl.metadata
#   Downloading langchain_openai-0.3.12-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: chromadb in c:\users\wahib\appdata\roaming\python\python311\site-packages (0.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in c:\programdata\anaconda3\lib\site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from openai) (4.12.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langchain) (0.3.48)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langchain) (0.3.18)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain) (6.0)
# Collecting langchain-core<1.0.0,>=0.3.45 (from langchain)
#   Obtaining dependency information for langchain-core<1.0.0,>=0.3.45 from https://files.pythonhosted.org/packages/01/78/39209de2ccc45a18e4bfa644a9846ec72831b464172b27dee156a622b599/langchain_core-0.3.50-py3-none-any.whl.metadata
#   Downloading langchain_core-0.3.50-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (0.115.12)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (1.26.2)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (3.21.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from chromadb) (0.13.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (3.10.16)
# Requirement already satisfied: rich>=10.11.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from chromadb) (13.7.0)
# Requirement already satisfied: idna>=2.8 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: packaging>=19.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\wahib\appdata\roaming\python\python311\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from fastapi>=0.95.2->chromadb) (0.46.1)
# Requirement already satisfied: certifi in c:\users\wahib\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\wahib\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (2.25.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\programdata\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\wahib\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.20)
# Requirement already satisfied: durationpy>=0.7 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in c:\users\wahib\appdata\roaming\python\python311\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\wahib\appdata\roaming\python\python311\site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\wahib\appdata\roaming\python\python311\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\programdata\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\programdata\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2022.7.9)
# Requirement already satisfied: click>=8.0.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (10.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.11.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\wahib\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Downloading langchain_openai-0.3.12-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.3 kB ? eta -:--:--
#    --------------------------------- ------ 51.2/61.3 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 61.3/61.3 kB 1.6 MB/s eta 0:00:00
# Downloading langchain_core-0.3.50-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.4 kB ? eta -:--:--
#    --------------------------------------  419.8/423.4 kB 13.2 MB/s eta 0:00:01
#    --------------------------------------- 423.4/423.4 kB 13.3 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain-openai
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.48
#     Uninstalling langchain-core-0.3.48:
#       Successfully uninstalled langchain-core-0.3.48
# Successfully installed langchain-core-0.3.50 langchain-openai-0.3.12

# %%
import os
import json
import openai
import fitz  # PyMuPDF pour extraire le texte des PDFs
from langdetect import detect  # Pour détecter la langue du texte
from dotenv import load_dotenv

# Charger les variables d'environnement
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
if not openai.api_key:
    raise ValueError("La clé API OpenAI n'a pas été trouvée. Vérifiez votre fichier .env.")

# Imports LangChain
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document

# 1. Fonction pour charger et traiter les PDFs
def charger_donnees_pdf(dossier_pdf):
    """
    Parcourt tous les fichiers PDF du dossier_pdf,
    extrait le texte et crée une liste de Documents LangChain.
    """
    documents = []
    for nom_fichier in os.listdir(dossier_pdf):
        if nom_fichier.endswith(".pdf"):
            chemin_fichier = os.path.join(dossier_pdf, nom_fichier)
            try:
                with fitz.open(chemin_fichier) as pdf:
                    texte = "".join(page.get_text("text") for page in pdf)
                    documents.append(
                        Document(
                            page_content=texte,
                            metadata={"source": nom_fichier, "langue": "en"}  # Tous les documents sont en anglais
                        )
                    )
            except Exception as e:
                print(f"❌ Erreur lors du traitement de {nom_fichier} : {e}")
    return documents

# 2. Fonction pour indexer les documents dans Chroma
def preparer_et_indexer_documents(documents, chemin_chroma):
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
    docs_split = splitter.split_documents(documents)
    embeddings = OpenAIEmbeddings(openai_api_key=openai.api_key)
    vecteur_store = Chroma(
        collection_name="preferences_services_eco_chatbot",
        embedding_function=embeddings,
        persist_directory=chemin_chroma
    )
    vecteur_store.add_documents(docs_split)
    vecteur_store.persist()
    return vecteur_store

# 3. Construire la chaîne RAG
def construire_chatbot(vectorstore, temperature=0.3):
    llm = ChatOpenAI(model_name="gpt-3.5-turbo", openai_api_key=openai.api_key, temperature=temperature)
    memoire = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
    return ConversationalRetrievalChain.from_llm(
        llm=llm,
        retriever=vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 4}),
        memory=memoire,
        verbose=True
    )

# 4. Mode interactif
def mode_terminal():
    print("\n🔍 Chargement et indexation des documents...")
    docs = charger_donnees_pdf("./load_documents_pdf")
    vecteurs = preparer_et_indexer_documents(docs, "./embeddings_pdf2")
    chatbot = construire_chatbot(vecteurs)
    print("\n🤖 Chatbot prêt ! Posez vos questions (ou tapez 'exit'):\n")
    
    while True:
        question = input("> ")
        if question.lower() in ["exit", "quit"]:
            break
        langue_utilisateur = detect(question)
        reponse = chatbot.invoke({"question": question})
        texte_reponse = reponse["answer"]
        
        # Assurer que la réponse est dans la même langue que la question
        if langue_utilisateur == "fr" and detect(texte_reponse) == "en":
            traduction = ChatOpenAI(model_name="gpt-4-turbo", openai_api_key=openai.api_key, temperature=0.3)
            texte_reponse = traduction.invoke(f"Traduisez en français: {texte_reponse}")
        elif langue_utilisateur == "en" and detect(texte_reponse) == "fr":
            traduction = ChatOpenAI(model_name="gpt-4-turbo", openai_api_key=openai.api_key, temperature=0.3)
            texte_reponse = traduction.invoke(f"Translate to English: {texte_reponse}")
        
        print("\n🧠 Réponse :", texte_reponse, "\n")

if __name__ == "__main__":
    mode_terminal()
# Out:
# 🔍 Chargement et indexation des documents...
# C:\Users\karriah dini\AppData\Local\Temp\ipykernel_53160\2231607593.py:50: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vecteur_store = Chroma(
# C:\Users\karriah dini\AppData\Local\Temp\ipykernel_53160\2231607593.py:56: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vecteur_store.persist()
# C:\Users\karriah dini\AppData\Local\Temp\ipykernel_53160\2231607593.py:62: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memoire = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
# 🤖 Chatbot prêt ! Posez vos questions (ou tapez 'exit'):
# ---------------------------------------------------------------------------
# LangDetectException                       Traceback (most recent call last)
# Cell In[1], line 97
#      94         print("\n🧠 Réponse :", texte_reponse, "\n")
#      96 if __name__ == "__main__":
# ---> 97     mode_terminal()
#
# Cell In[1], line 82, in mode_terminal()
#      80 if question.lower() in ["exit", "quit"]:
#      81     break
# ---> 82 langue_utilisateur = detect(question)
#      83 reponse = chatbot.invoke({"question": question})
#      84 texte_reponse = reponse["answer"]
#
# File c:\Users\karriah dini\AppData\Local\Programs\Python\Python312\Lib\site-packages\langdetect\detector_factory.py:130, in detect(text)
#     128 detector = _factory.create()
#     129 detector.append(text)
# --> 130 return detector.detect()
#
# File c:\Users\karriah dini\AppData\Local\Programs\Python\Python312\Lib\site-packages\langdetect\detector.py:136, in Detector.detect(self)
#     132 def detect(self):
#     133     '''Detect language of the target text and return the language name
#     134     which has the highest probability.
#     135     '''
# --> 136     probabilities = self.get_probabilities()
#     137     if probabilities:
#     138         return probabilities[0].lang
#
# File c:\Users\karriah dini\AppData\Local\Programs\Python\Python312\Lib\site-packages\langdetect\detector.py:143, in Detector.get_probabilities(self)
#     141 def get_probabilities(self):
#     142     if self.langprob is None:
# --> 143         self._detect_block()
#     144     return self._sort_probability(self.langprob)
#
# File c:\Users\karriah dini\AppData\Local\Programs\Python\Python312\Lib\site-packages\langdetect\detector.py:150, in Detector._detect_block(self)
#     148 ngrams = self._extract_ngrams()
#     149 if not ngrams:
# --> 150     raise LangDetectException(ErrorCode.CantDetectError, 'No features in text.')
#     152 self.langprob = [0.0] * len(self.langlist)
#     154 self.random.seed(self.seed)
#
# LangDetectException: No features in text.
